# %%
# Importing necessary dependencies

import pandas as pd
import requests
import numpy as np
from citipy import citipy
import time

# %%
# Creating a random set of latitude and longitude combinations, and saving to temporary memory
lats = np.random.uniform(low = -90.000, high = 90.000, size = 2000)
lngs = np.random.uniform(low = -180.000, high = 180.000, size = 2000)
lat_lngs = zip(lats, lngs)

lat_lngs

# %%
# Saving the lat and lng pairs as a list
coordinates = list(lat_lngs)

# %%
# Importing API key, and setting up url to get weather data
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Creating a list of cities closest to coordinates
# First creating a list to hold the cities
cities = []

# Identify the nearest city to coordinate pairs using a for loop
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate [1]).city_name
    
    # Ensuring only unique cities added
    if city not in cities:
        cities.append(city)
        
# Printing city count
len(cities)
# Out:
# 720

# %%
# Creating empty list to hold weather data
city_data = []

# Print the beginning of the logging
print("Beginning the Data Retrieval     ")
print("---------------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through cities in th list 
for i, city in enumerate(cities):
    
    # Grouping cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create the endpoint url for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URl, record, set numbersm adn the city
    print(f"Processing record {record_count} of Set {set_count} | {city}")\
    
    # Ad 1 to the record count
    record_count += 1
    
    # Run an APi request fort each of the cities
    try: 
        # Parse the JSON and retrieve the data
        city_weather = requests.get(city_url).json()

        # Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]

        # Add all of this data to the city_data list
        city_data.append({
            "City": city.title(),
            "Country": city_country,
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Current Description": city_description
        })
    # If an error occurs, skip that city
    except:
        print(f"City not found, skipping... {city}")
        continue
    
# Indicate that data laoding is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning the Data Retrieval
# ---------------------------------
# Processing record 1 of Set 1 | saskylakh
# Processing record 2 of Set 1 | atuona
# Processing record 3 of Set 1 | udachnyy
# Processing record 4 of Set 1 | hermanus
# Processing record 5 of Set 1 | lubango
# Processing record 6 of Set 1 | khatanga
# Processing record 7 of Set 1 | mataura
# Processing record 8 of Set 1 | nikolskoye
# Processing record 9 of Set 1 | pangody
# Processing record 10 of Set 1 | bluff
# Processing record 11 of Set 1 | bredasdorp
# Processing record 12 of Set 1 | albany
# Processing record 13 of Set 1 | ribeira grande
# Processing record 14 of Set 1 | dicabisagan
# Processing record 15 of Set 1 | punta arenas
# Processing record 16 of Set 1 | rikitea
# Processing record 17 of Set 1 | biak
# Processing record 18 of Set 1 | east london
# Processing record 19 of Set 1 | gorodovikovsk
# Processing record 20 of Set 1 | illoqqortoormiut
# City not found, skipping... illoqqortoormiut
# Processing record 21 of Set 1 | vardo
# Processing record 22 of Set 1 | castro
# Processing record 23 of Set 1 | linguere
# Processing record 24 of Set 1 | tumannyy
# City not found, skipping... tumannyy
# Processing record 25 of Set 1 | ushuaia
# Processing record 26 of Set 1 | waspan
# Processing record 27 of Set 1 | belushya guba
# City not found, skipping... belushya guba
# Processing record 28 of Set 1 | cherskiy
# Processing record 29 of Set 1 | tiksi
# Processing record 30 of Set 1 | magistralnyy
# Processing record 31 of Set 1 | provideniya
# Processing record 32 of Set 1 | carnarvon
# Processing record 33 of Set 1 | sungaipenuh
# Processing record 34 of Set 1 | new norfolk
# Processing record 35 of Set 1 | cockburn town
# Processing record 36 of Set 1 | cururupu
# Processing record 37 of Set 1 | tasiilaq
# Processing record 38 of Set 1 | saint-philippe
# Processing record 39 of Set 1 | barrow
# Processing record 40 of Set 1 | zhigansk
# Processing record 41 of Set 1 | constitucion
# Processing record 42 of Set 1 | nara
# Processing record 43 of Set 1 | hithadhoo
# Processing record 44 of Set 1 | asau
# Processing record 45 of Set 1 | tutoia
# Processing record 46 of Set 1 | nhulunbuy
# Processing record 47 of Set 1 | clyde river
# Processing record 48 of Set 1 | saint george
# Processing record 49 of Set 1 | baykit
# Processing record 50 of Set 1 | arica
# Processing record 1 of Set 2 | black forest
# Processing record 2 of Set 2 | sitka
# Processing record 3 of Set 2 | port alfred
# Processing record 4 of Set 2 | jamestown
# Processing record 5 of Set 2 | cape town
# Processing record 6 of Set 2 | amderma
# City not found, skipping... amderma
# Processing record 7 of Set 2 | butaritari
# Processing record 8 of Set 2 | smithers
# Processing record 9 of Set 2 | acapulco
# Processing record 10 of Set 2 | salinopolis
# Processing record 11 of Set 2 | grand gaube
# Processing record 12 of Set 2 | broken hill
# Processing record 13 of Set 2 | altamont
# Processing record 14 of Set 2 | flinders
# Processing record 15 of Set 2 | puerto ayora
# Processing record 16 of Set 2 | clarence town
# Processing record 17 of Set 2 | xai-xai
# Processing record 18 of Set 2 | tianpeng
# Processing record 19 of Set 2 | ancud
# Processing record 20 of Set 2 | mar del plata
# Processing record 21 of Set 2 | gusau
# Processing record 22 of Set 2 | avarua
# Processing record 23 of Set 2 | hobart
# Processing record 24 of Set 2 | high level
# Processing record 25 of Set 2 | ponta do sol
# Processing record 26 of Set 2 | qaanaaq
# Processing record 27 of Set 2 | mackay
# Processing record 28 of Set 2 | ilulissat
# Processing record 29 of Set 2 | caluquembe
# Processing record 30 of Set 2 | hailey
# Processing record 31 of Set 2 | parana
# Processing record 32 of Set 2 | ludvika
# Processing record 33 of Set 2 | norrtalje
# Processing record 34 of Set 2 | benalla
# Processing record 35 of Set 2 | vaini
# Processing record 36 of Set 2 | camacha
# Processing record 37 of Set 2 | taolanaro
# City not found, skipping... taolanaro
# Processing record 38 of Set 2 | san ignacio de sabaneta
# City not found, skipping... san ignacio de sabaneta
# Processing record 39 of Set 2 | laguna
# Processing record 40 of Set 2 | preobrazheniye
# Processing record 41 of Set 2 | berlevag
# Processing record 42 of Set 2 | busselton
# Processing record 43 of Set 2 | sept-iles
# Processing record 44 of Set 2 | tuktoyaktuk
# Processing record 45 of Set 2 | los llanos de aridane
# Processing record 46 of Set 2 | port hawkesbury
# Processing record 47 of Set 2 | naze
# Processing record 48 of Set 2 | victoria
# Processing record 49 of Set 2 | bonthe
# Processing record 50 of Set 2 | san borja
# Processing record 1 of Set 3 | sorvag
# City not found, skipping... sorvag
# Processing record 2 of Set 3 | nome
# Processing record 3 of Set 3 | bambous virieux
# Processing record 4 of Set 3 | hilo
# Processing record 5 of Set 3 | barbar
# City not found, skipping... barbar
# Processing record 6 of Set 3 | sarankhola
# Processing record 7 of Set 3 | torbay
# Processing record 8 of Set 3 | akdepe
# Processing record 9 of Set 3 | soyo
# Processing record 10 of Set 3 | ponta delgada
# Processing record 11 of Set 3 | faanui
# Processing record 12 of Set 3 | lebu
# Processing record 13 of Set 3 | freeport
# Processing record 14 of Set 3 | sao filipe
# Processing record 15 of Set 3 | les cayes
# Processing record 16 of Set 3 | mangan
# Processing record 17 of Set 3 | roald
# Processing record 18 of Set 3 | novyy urengoy
# Processing record 19 of Set 3 | faya
# Processing record 20 of Set 3 | grand-santi
# Processing record 21 of Set 3 | kuryk
# Processing record 22 of Set 3 | kaitangata
# Processing record 23 of Set 3 | lavrentiya
# Processing record 24 of Set 3 | port hardy
# Processing record 25 of Set 3 | pevek
# Processing record 26 of Set 3 | codrington
# Processing record 27 of Set 3 | tyshkivka
# Processing record 28 of Set 3 | knysna
# Processing record 29 of Set 3 | katsuura
# Processing record 30 of Set 3 | kindu
# Processing record 31 of Set 3 | kavaratti
# Processing record 32 of Set 3 | ordzhonikidzevskaya
# Processing record 33 of Set 3 | pilar
# Processing record 34 of Set 3 | wyndham
# Processing record 35 of Set 3 | del rio
# Processing record 36 of Set 3 | patacamaya
# Processing record 37 of Set 3 | havelock
# Processing record 38 of Set 3 | lichinga
# Processing record 39 of Set 3 | geraldton
# Processing record 40 of Set 3 | houston
# Processing record 41 of Set 3 | halifax
# Processing record 42 of Set 3 | kamenskoye
# City not found, skipping... kamenskoye
# Processing record 43 of Set 3 | quatre cocos
# Processing record 44 of Set 3 | babanusah
# City not found, skipping... babanusah
# Processing record 45 of Set 3 | dikson
# Processing record 46 of Set 3 | kloulklubed
# Processing record 47 of Set 3 | hasaki
# Processing record 48 of Set 3 | san carlos de bariloche
# Processing record 49 of Set 3 | mahebourg
# Processing record 50 of Set 3 | kushima
# Processing record 1 of Set 4 | sungairaya
# Processing record 2 of Set 4 | kapaa
# Processing record 3 of Set 4 | idrinskoye
# Processing record 4 of Set 4 | yellowknife
# Processing record 5 of Set 4 | mormugao
# Processing record 6 of Set 4 | sakakah
# Processing record 7 of Set 4 | palauig
# Processing record 8 of Set 4 | niquero
# Processing record 9 of Set 4 | attawapiskat
# City not found, skipping... attawapiskat
# Processing record 10 of Set 4 | longyearbyen
# Processing record 11 of Set 4 | adrar
# Processing record 12 of Set 4 | sao felix do xingu
# Processing record 13 of Set 4 | posse
# Processing record 14 of Set 4 | kalangala
# Processing record 15 of Set 4 | lagoa
# Processing record 16 of Set 4 | meulaboh
# Processing record 17 of Set 4 | del pilar
# Processing record 18 of Set 4 | cam pha
# City not found, skipping... cam pha
# Processing record 19 of Set 4 | cayenne
# Processing record 20 of Set 4 | gopichettipalaiyam
# City not found, skipping... gopichettipalaiyam
# Processing record 21 of Set 4 | hofn
# Processing record 22 of Set 4 | verkhnevilyuysk
# Processing record 23 of Set 4 | kirakira
# Processing record 24 of Set 4 | esperance
# Processing record 25 of Set 4 | nemuro
# Processing record 26 of Set 4 | bursa
# Processing record 27 of Set 4 | yarada
# Processing record 28 of Set 4 | esik
# Processing record 29 of Set 4 | coihaique
# Processing record 30 of Set 4 | goderich
# Processing record 31 of Set 4 | port macquarie
# Processing record 32 of Set 4 | souillac
# Processing record 33 of Set 4 | mys shmidta
# City not found, skipping... mys shmidta
# Processing record 34 of Set 4 | borovoy
# Processing record 35 of Set 4 | arraial do cabo
# Processing record 36 of Set 4 | moose factory
# Processing record 37 of Set 4 | narsaq
# Processing record 38 of Set 4 | santa maria
# Processing record 39 of Set 4 | severo-kurilsk
# Processing record 40 of Set 4 | moranbah
# Processing record 41 of Set 4 | puerto del rosario
# Processing record 42 of Set 4 | deoria
# Processing record 43 of Set 4 | deputatskiy
# Processing record 44 of Set 4 | westport
# Processing record 45 of Set 4 | tsihombe
# City not found, skipping... tsihombe
# Processing record 46 of Set 4 | lephepe
# City not found, skipping... lephepe
# Processing record 47 of Set 4 | port blair
# Processing record 48 of Set 4 | lorengau
# Processing record 49 of Set 4 | florianopolis
# Processing record 50 of Set 4 | talnakh
# Processing record 1 of Set 5 | lambarene
# Processing record 2 of Set 5 | stokmarknes
# Processing record 3 of Set 5 | najran
# Processing record 4 of Set 5 | kupang
# Processing record 5 of Set 5 | tessalit
# Processing record 6 of Set 5 | taltal
# Processing record 7 of Set 5 | aginskoye
# Processing record 8 of Set 5 | lake havasu city
# Processing record 9 of Set 5 | togur
# Processing record 10 of Set 5 | karabanovo
# Processing record 11 of Set 5 | hutchinson
# Processing record 12 of Set 5 | fairbanks
# Processing record 13 of Set 5 | glubokoe
# City not found, skipping... glubokoe
# Processing record 14 of Set 5 | tiruvottiyur
# City not found, skipping... tiruvottiyur
# Processing record 15 of Set 5 | baherden
# Processing record 16 of Set 5 | arman
# Processing record 17 of Set 5 | upernavik
# Processing record 18 of Set 5 | virginia beach
# Processing record 19 of Set 5 | saleaula
# City not found, skipping... saleaula
# Processing record 20 of Set 5 | halesowen
# Processing record 21 of Set 5 | salina
# Processing record 22 of Set 5 | yumen
# Processing record 23 of Set 5 | cidreira
# Processing record 24 of Set 5 | scarborough
# Processing record 25 of Set 5 | muros
# Processing record 26 of Set 5 | bethel
# Processing record 27 of Set 5 | kaka
# Processing record 28 of Set 5 | kodiak
# Processing record 29 of Set 5 | lompoc
# Processing record 30 of Set 5 | teya
# Processing record 31 of Set 5 | hualmay
# Processing record 32 of Set 5 | marquette
# Processing record 33 of Set 5 | susanville
# Processing record 34 of Set 5 | yerbogachen
# Processing record 35 of Set 5 | ouesso
# Processing record 36 of Set 5 | utiroa
# City not found, skipping... utiroa
# Processing record 37 of Set 5 | avera
# Processing record 38 of Set 5 | ayr
# Processing record 39 of Set 5 | tosya
# Processing record 40 of Set 5 | kruisfontein
# Processing record 41 of Set 5 | nizhneyansk
# City not found, skipping... nizhneyansk
# Processing record 42 of Set 5 | rio gallegos
# Processing record 43 of Set 5 | vaitupu
# City not found, skipping... vaitupu
# Processing record 44 of Set 5 | ahipara
# Processing record 45 of Set 5 | marawi
# Processing record 46 of Set 5 | emerald
# Processing record 47 of Set 5 | airai
# Processing record 48 of Set 5 | kidal
# Processing record 49 of Set 5 | barentsburg
# City not found, skipping... barentsburg
# Processing record 50 of Set 5 | brae
# Processing record 1 of Set 6 | douentza
# Processing record 2 of Set 6 | richards bay
# Processing record 3 of Set 6 | fortuna
# Processing record 4 of Set 6 | port lincoln
# Processing record 5 of Set 6 | georgetown
# Processing record 6 of Set 6 | huarmey
# Processing record 7 of Set 6 | ust-nera
# Processing record 8 of Set 6 | taburi
# City not found, skipping... taburi
# Processing record 9 of Set 6 | berdigestyakh
# Processing record 10 of Set 6 | sao joao da barra
# Processing record 11 of Set 6 | kampene
# Processing record 12 of Set 6 | tautira
# Processing record 13 of Set 6 | ketchikan
# Processing record 14 of Set 6 | nanortalik
# Processing record 15 of Set 6 | paamiut
# Processing record 16 of Set 6 | palmer
# Processing record 17 of Set 6 | phulji
# Processing record 18 of Set 6 | okhotsk
# Processing record 19 of Set 6 | tete
# Processing record 20 of Set 6 | prince rupert
# Processing record 21 of Set 6 | inirida
# Processing record 22 of Set 6 | vao
# Processing record 23 of Set 6 | ruidoso
# Processing record 24 of Set 6 | yichang
# Processing record 25 of Set 6 | chokurdakh
# Processing record 26 of Set 6 | sur
# Processing record 27 of Set 6 | orkney
# Processing record 28 of Set 6 | cabo san lucas
# Processing record 29 of Set 6 | kristinehamn
# Processing record 30 of Set 6 | elblag
# Processing record 31 of Set 6 | mwingi
# Processing record 32 of Set 6 | saldanha
# Processing record 33 of Set 6 | guerrero negro
# Processing record 34 of Set 6 | zwedru
# Processing record 35 of Set 6 | sokolo
# Processing record 36 of Set 6 | shimoda
# Processing record 37 of Set 6 | bolungarvik
# City not found, skipping... bolungarvik
# Processing record 38 of Set 6 | ville-marie
# Processing record 39 of Set 6 | portland
# Processing record 40 of Set 6 | aitape
# Processing record 41 of Set 6 | houma
# Processing record 42 of Set 6 | thompson
# Processing record 43 of Set 6 | mahon
# Processing record 44 of Set 6 | saint-pierre
# Processing record 45 of Set 6 | ola
# Processing record 46 of Set 6 | balint
# Processing record 47 of Set 6 | kununurra
# Processing record 48 of Set 6 | mount gambier
# Processing record 49 of Set 6 | asfi
# Processing record 50 of Set 6 | campo gobierno
# Processing record 1 of Set 7 | churapcha
# Processing record 2 of Set 7 | plouzane
# Processing record 3 of Set 7 | camana
# Processing record 4 of Set 7 | oussouye
# Processing record 5 of Set 7 | kang
# Processing record 6 of Set 7 | atar
# Processing record 7 of Set 7 | barra do garcas
# Processing record 8 of Set 7 | yar-sale
# Processing record 9 of Set 7 | kavieng
# Processing record 10 of Set 7 | salamiyah
# Processing record 11 of Set 7 | duz
# City not found, skipping... duz
# Processing record 12 of Set 7 | leningradskiy
# Processing record 13 of Set 7 | puerto padre
# Processing record 14 of Set 7 | libreville
# Processing record 15 of Set 7 | visnes
# Processing record 16 of Set 7 | maragogi
# Processing record 17 of Set 7 | puerto colombia
# Processing record 18 of Set 7 | bubaque
# Processing record 19 of Set 7 | xining
# Processing record 20 of Set 7 | rawson
# Processing record 21 of Set 7 | inta
# Processing record 22 of Set 7 | lumeje
# Processing record 23 of Set 7 | isangel
# Processing record 24 of Set 7 | samarai
# Processing record 25 of Set 7 | waingapu
# Processing record 26 of Set 7 | dimitrovgrad
# Processing record 27 of Set 7 | shingu
# Processing record 28 of Set 7 | marcona
# City not found, skipping... marcona
# Processing record 29 of Set 7 | grand river south east
# City not found, skipping... grand river south east
# Processing record 30 of Set 7 | riyadh
# Processing record 31 of Set 7 | placido de castro
# Processing record 32 of Set 7 | omsukchan
# Processing record 33 of Set 7 | nouadhibou
# Processing record 34 of Set 7 | bakonycsernye
# Processing record 35 of Set 7 | cap malheureux
# Processing record 36 of Set 7 | tombouctou
# Processing record 37 of Set 7 | kerema
# Processing record 38 of Set 7 | andenes
# Processing record 39 of Set 7 | akyab
# Processing record 40 of Set 7 | tuatapere
# Processing record 41 of Set 7 | fenoarivo
# Processing record 42 of Set 7 | sao luiz gonzaga
# Processing record 43 of Set 7 | mwense
# Processing record 44 of Set 7 | menongue
# Processing record 45 of Set 7 | neuquen
# Processing record 46 of Set 7 | lefka
# Processing record 47 of Set 7 | fare
# Processing record 48 of Set 7 | jalu
# Processing record 49 of Set 7 | karratha
# Processing record 50 of Set 7 | altay
# Processing record 1 of Set 8 | salalah
# Processing record 2 of Set 8 | dingle
# Processing record 3 of Set 8 | divnomorskoye
# Processing record 4 of Set 8 | shirwal
# Processing record 5 of Set 8 | matara
# Processing record 6 of Set 8 | pisco
# Processing record 7 of Set 8 | fort nelson
# Processing record 8 of Set 8 | wad rawah
# Processing record 9 of Set 8 | ixtapa
# Processing record 10 of Set 8 | chilliwack
# Processing record 11 of Set 8 | lipin bor
# Processing record 12 of Set 8 | lethem
# Processing record 13 of Set 8 | sinkat
# City not found, skipping... sinkat
# Processing record 14 of Set 8 | sal rei
# Processing record 15 of Set 8 | aizawl
# Processing record 16 of Set 8 | corinto
# Processing record 17 of Set 8 | tonota
# Processing record 18 of Set 8 | kichera
# Processing record 19 of Set 8 | taft
# Processing record 20 of Set 8 | mangrol
# Processing record 21 of Set 8 | gidam
# Processing record 22 of Set 8 | bandarbeyla
# Processing record 23 of Set 8 | aswan
# Processing record 24 of Set 8 | ndjole
# Processing record 25 of Set 8 | canitas
# City not found, skipping... canitas
# Processing record 26 of Set 8 | sehithwa
# Processing record 27 of Set 8 | solsvik
# City not found, skipping... solsvik
# Processing record 28 of Set 8 | tucupita
# Processing record 29 of Set 8 | puri
# Processing record 30 of Set 8 | haapu
# City not found, skipping... haapu
# Processing record 31 of Set 8 | kilindoni
# Processing record 32 of Set 8 | ostrovnoy
# Processing record 33 of Set 8 | touros
# Processing record 34 of Set 8 | stornoway
# Processing record 35 of Set 8 | bontang
# Processing record 36 of Set 8 | vestmannaeyjar
# Processing record 37 of Set 8 | ostersund
# Processing record 38 of Set 8 | taoudenni
# Processing record 39 of Set 8 | coquimbo
# Processing record 40 of Set 8 | znamenskoye
# Processing record 41 of Set 8 | iqaluit
# Processing record 42 of Set 8 | addis abeba
# Processing record 43 of Set 8 | ericeira
# Processing record 44 of Set 8 | kamenka
# Processing record 45 of Set 8 | bayir
# Processing record 46 of Set 8 | tateyama
# Processing record 47 of Set 8 | galiwinku
# City not found, skipping... galiwinku
# Processing record 48 of Set 8 | sosnovka
# Processing record 49 of Set 8 | sinnamary
# Processing record 50 of Set 8 | itoman
# Processing record 1 of Set 9 | the valley
# Processing record 2 of Set 9 | wahpeton
# Processing record 3 of Set 9 | banepa
# Processing record 4 of Set 9 | denpasar
# Processing record 5 of Set 9 | norman wells
# Processing record 6 of Set 9 | urucara
# Processing record 7 of Set 9 | sambava
# Processing record 8 of Set 9 | tuskegee
# Processing record 9 of Set 9 | bengkulu
# Processing record 10 of Set 9 | podor
# Processing record 11 of Set 9 | port elizabeth
# Processing record 12 of Set 9 | steamboat springs
# Processing record 13 of Set 9 | fuxin
# Processing record 14 of Set 9 | chincha alta
# Processing record 15 of Set 9 | fukue
# Processing record 16 of Set 9 | bolshoye soldatskoye
# City not found, skipping... bolshoye soldatskoye
# Processing record 17 of Set 9 | derbent
# Processing record 18 of Set 9 | domoni
# Processing record 19 of Set 9 | kieta
# Processing record 20 of Set 9 | talesh
# City not found, skipping... talesh
# Processing record 21 of Set 9 | mikuni
# Processing record 22 of Set 9 | baculin
# Processing record 23 of Set 9 | kota kinabalu
# Processing record 24 of Set 9 | samusu
# City not found, skipping... samusu
# Processing record 25 of Set 9 | tarudant
# City not found, skipping... tarudant
# Processing record 26 of Set 9 | honningsvag
# Processing record 27 of Set 9 | walvis bay
# Processing record 28 of Set 9 | amapa
# Processing record 29 of Set 9 | mwinilunga
# Processing record 30 of Set 9 | krasnoselkup
# Processing record 31 of Set 9 | laranjeiras do sul
# Processing record 32 of Set 9 | rivadavia
# Processing record 33 of Set 9 | lengshuijiang
# Processing record 34 of Set 9 | seymchan
# Processing record 35 of Set 9 | san patricio
# Processing record 36 of Set 9 | seoul
# Processing record 37 of Set 9 | necochea
# Processing record 38 of Set 9 | huejuquilla el alto
# Processing record 39 of Set 9 | tiarei
# Processing record 40 of Set 9 | plettenberg bay
# Processing record 41 of Set 9 | okha
# Processing record 42 of Set 9 | green river
# Processing record 43 of Set 9 | grindavik
# Processing record 44 of Set 9 | flin flon
# Processing record 45 of Set 9 | port augusta
# Processing record 46 of Set 9 | pacifica
# Processing record 47 of Set 9 | korla
# Processing record 48 of Set 9 | rosetta
# Processing record 49 of Set 9 | minab
# Processing record 50 of Set 9 | korgen
# Processing record 1 of Set 10 | wattegama
# Processing record 2 of Set 10 | tambacounda
# Processing record 3 of Set 10 | soure
# Processing record 4 of Set 10 | nushki
# Processing record 5 of Set 10 | beringovskiy
# Processing record 6 of Set 10 | tilichiki
# Processing record 7 of Set 10 | north bend
# Processing record 8 of Set 10 | cam ranh
# Processing record 9 of Set 10 | namibe
# Processing record 10 of Set 10 | kahului
# Processing record 11 of Set 10 | yeppoon
# Processing record 12 of Set 10 | batalha
# Processing record 13 of Set 10 | provost
# Processing record 14 of Set 10 | abha
# Processing record 15 of Set 10 | venado tuerto
# Processing record 16 of Set 10 | passo fundo
# Processing record 17 of Set 10 | sisimiut
# Processing record 18 of Set 10 | vila velha
# Processing record 19 of Set 10 | peleduy
# Processing record 20 of Set 10 | dubbo
# Processing record 21 of Set 10 | maniitsoq
# Processing record 22 of Set 10 | luganville
# Processing record 23 of Set 10 | taucha
# Processing record 24 of Set 10 | kamaishi
# Processing record 25 of Set 10 | tanout
# Processing record 26 of Set 10 | chicama
# Processing record 27 of Set 10 | christchurch
# Processing record 28 of Set 10 | merrill
# Processing record 29 of Set 10 | alice springs
# Processing record 30 of Set 10 | leh
# Processing record 31 of Set 10 | truth or consequences
# Processing record 32 of Set 10 | klaksvik
# Processing record 33 of Set 10 | alamogordo
# Processing record 34 of Set 10 | danjiangkou
# Processing record 35 of Set 10 | lingdong
# Processing record 36 of Set 10 | padang
# Processing record 37 of Set 10 | kropotkin
# Processing record 38 of Set 10 | canton
# Processing record 39 of Set 10 | mezen
# Processing record 40 of Set 10 | buala
# Processing record 41 of Set 10 | caravelas
# Processing record 42 of Set 10 | tairua
# Processing record 43 of Set 10 | puerto palomas
# Processing record 44 of Set 10 | aurangabad
# Processing record 45 of Set 10 | corovode
# Processing record 46 of Set 10 | saint augustine
# Processing record 47 of Set 10 | mitsamiouli
# Processing record 48 of Set 10 | ahuimanu
# Processing record 49 of Set 10 | san antonio
# Processing record 50 of Set 10 | kyren
# Processing record 1 of Set 11 | qeshm
# Processing record 2 of Set 11 | tsaratanana
# Processing record 3 of Set 11 | chaves
# Processing record 4 of Set 11 | porto novo
# Processing record 5 of Set 11 | bilma
# Processing record 6 of Set 11 | ngunguru
# Processing record 7 of Set 11 | bairiki
# Processing record 8 of Set 11 | puerto escondido
# Processing record 9 of Set 11 | dunedin
# Processing record 10 of Set 11 | wangaratta
# Processing record 11 of Set 11 | santa isabel do rio negro
# Processing record 12 of Set 11 | svetlogorsk
# Processing record 13 of Set 11 | bathsheba
# Processing record 14 of Set 11 | olafsvik
# Processing record 15 of Set 11 | sinaloa
# Processing record 16 of Set 11 | khandyga
# Processing record 17 of Set 11 | mahibadhoo
# Processing record 18 of Set 11 | vanimo
# Processing record 19 of Set 11 | voiste
# City not found, skipping... voiste
# Processing record 20 of Set 11 | vanderhoof
# Processing record 21 of Set 11 | cap-aux-meules
# Processing record 22 of Set 11 | kirkenaer
# Processing record 23 of Set 11 | charters towers
# Processing record 24 of Set 11 | saint anthony
# Processing record 25 of Set 11 | iskateley
# Processing record 26 of Set 11 | srednekolymsk
# Processing record 27 of Set 11 | prince george
# Processing record 28 of Set 11 | ruatoria
# City not found, skipping... ruatoria
# Processing record 29 of Set 11 | matagami
# Processing record 30 of Set 11 | loandjili
# Processing record 31 of Set 11 | sheridan
# Processing record 32 of Set 11 | shahr-e babak
# Processing record 33 of Set 11 | husavik
# Processing record 34 of Set 11 | tocopilla
# Processing record 35 of Set 11 | eydhafushi
# Processing record 36 of Set 11 | tourlaville
# Processing record 37 of Set 11 | babu
# Processing record 38 of Set 11 | tolga
# Processing record 39 of Set 11 | luena
# Processing record 40 of Set 11 | kiama
# Processing record 41 of Set 11 | nantucket
# Processing record 42 of Set 11 | laredo
# Processing record 43 of Set 11 | zapolyarnyy
# Processing record 44 of Set 11 | pakxan
# Processing record 45 of Set 11 | porbandar
# Processing record 46 of Set 11 | vaasa
# Processing record 47 of Set 11 | lakselv
# Processing record 48 of Set 11 | koungou
# Processing record 49 of Set 11 | calderitas
# Processing record 50 of Set 11 | sentyabrskiy
# City not found, skipping... sentyabrskiy
# Processing record 1 of Set 12 | andilamena
# Processing record 2 of Set 12 | zhanakorgan
# Processing record 3 of Set 12 | dalby
# Processing record 4 of Set 12 | chase
# Processing record 5 of Set 12 | gwadar
# Processing record 6 of Set 12 | caceres
# Processing record 7 of Set 12 | emba
# Processing record 8 of Set 12 | birobidzhan
# Processing record 9 of Set 12 | sofiysk
# City not found, skipping... sofiysk
# Processing record 10 of Set 12 | thinadhoo
# Processing record 11 of Set 12 | solnechnyy
# Processing record 12 of Set 12 | rudbar
# Processing record 13 of Set 12 | dneprovskaya
# Processing record 14 of Set 12 | beloha
# Processing record 15 of Set 12 | tokzar
# City not found, skipping... tokzar
# Processing record 16 of Set 12 | vanavara
# Processing record 17 of Set 12 | santa rosa
# Processing record 18 of Set 12 | mazatlan
# Processing record 19 of Set 12 | kimbe
# Processing record 20 of Set 12 | ypsilanti
# Processing record 21 of Set 12 | santo antonio do ica
# Processing record 22 of Set 12 | sedelnikovo
# City not found, skipping... sedelnikovo
# Processing record 23 of Set 12 | bloemfontein
# Processing record 24 of Set 12 | roma
# Processing record 25 of Set 12 | sao miguel do araguaia
# Processing record 26 of Set 12 | seuzach
# Processing record 27 of Set 12 | ewa beach
# Processing record 28 of Set 12 | taguatinga
# Processing record 29 of Set 12 | koutiala
# Processing record 30 of Set 12 | kitimat
# Processing record 31 of Set 12 | carutapera
# Processing record 32 of Set 12 | timra
# Processing record 33 of Set 12 | batatais
# Processing record 34 of Set 12 | wasilla
# Processing record 35 of Set 12 | rumphi
# Processing record 36 of Set 12 | rio hondo
# Processing record 37 of Set 12 | nalut
# Processing record 38 of Set 12 | kaeo
# Processing record 39 of Set 12 | fort morgan
# Processing record 40 of Set 12 | haines junction
# Processing record 41 of Set 12 | ust-kuyga
# Processing record 42 of Set 12 | slave lake
# Processing record 43 of Set 12 | ca mau
# Processing record 44 of Set 12 | dekoa
# City not found, skipping... dekoa
# Processing record 45 of Set 12 | tokur
# Processing record 46 of Set 12 | bilibino
# Processing record 47 of Set 12 | umm kaddadah
# Processing record 48 of Set 12 | sembe
# Processing record 49 of Set 12 | villamontes
# Processing record 50 of Set 12 | bridlington
# Processing record 1 of Set 13 | mayumba
# Processing record 2 of Set 13 | cecina
# Processing record 3 of Set 13 | pyinmana
# Processing record 4 of Set 13 | kyabram
# Processing record 5 of Set 13 | gizo
# Processing record 6 of Set 13 | henties bay
# Processing record 7 of Set 13 | pangai
# Processing record 8 of Set 13 | rungata
# City not found, skipping... rungata
# Processing record 9 of Set 13 | altamira
# Processing record 10 of Set 13 | watsa
# Processing record 11 of Set 13 | oktyabrskiy
# Processing record 12 of Set 13 | penzance
# Processing record 13 of Set 13 | bibiani
# Processing record 14 of Set 13 | shubarkuduk
# Processing record 15 of Set 13 | mehamn
# Processing record 16 of Set 13 | oxapampa
# Processing record 17 of Set 13 | shenjiamen
# Processing record 18 of Set 13 | axim
# Processing record 19 of Set 13 | evensk
# Processing record 20 of Set 13 | uige
# Processing record 21 of Set 13 | havre-saint-pierre
# Processing record 22 of Set 13 | pokhara
# Processing record 23 of Set 13 | edeia
# Processing record 24 of Set 13 | shetpe
# Processing record 25 of Set 13 | nishihara
# Processing record 26 of Set 13 | martapura
# Processing record 27 of Set 13 | ngaoundere
# Processing record 28 of Set 13 | tymovskoye
# Processing record 29 of Set 13 | rantepao
# Processing record 30 of Set 13 | sabang
# Processing record 31 of Set 13 | paragominas
# Processing record 32 of Set 13 | aykhal
# Processing record 33 of Set 13 | cozumel
# Processing record 34 of Set 13 | la ronge
# Processing record 35 of Set 13 | craig
# Processing record 36 of Set 13 | lumphat
# Processing record 37 of Set 13 | rocha
# Processing record 38 of Set 13 | dawlatabad
# Processing record 39 of Set 13 | sobolevo
# Processing record 40 of Set 13 | mazagao
# Processing record 41 of Set 13 | port alberni
# Processing record 42 of Set 13 | wynyard
# Processing record 43 of Set 13 | aklavik
# Processing record 44 of Set 13 | nelson bay
# Processing record 45 of Set 13 | mandera
# Processing record 46 of Set 13 | nuling
# City not found, skipping... nuling
# Processing record 47 of Set 13 | kuopio
# Processing record 48 of Set 13 | ulaangom
# Processing record 49 of Set 13 | bagenalstown
# Processing record 50 of Set 13 | lesogorsk
# Processing record 1 of Set 14 | derzhavinsk
# Processing record 2 of Set 14 | puerto leguizamo
# Processing record 3 of Set 14 | pimenta bueno
# Processing record 4 of Set 14 | porto belo
# Processing record 5 of Set 14 | thunder bay
# Processing record 6 of Set 14 | vilyuysk
# Processing record 7 of Set 14 | labuhan
# Processing record 8 of Set 14 | gonda
# Processing record 9 of Set 14 | despotovac
# Processing record 10 of Set 14 | pergamino
# Processing record 11 of Set 14 | mecca
# Processing record 12 of Set 14 | dresden
# Processing record 13 of Set 14 | dom pedrito
# Processing record 14 of Set 14 | micheweni
# Processing record 15 of Set 14 | zabaykalsk
# Processing record 16 of Set 14 | takoradi
# Processing record 17 of Set 14 | san alejo
# Processing record 18 of Set 14 | lazaro cardenas
# Processing record 19 of Set 14 | qujing
# Processing record 20 of Set 14 | nautla
# Processing record 21 of Set 14 | marrakesh
# Processing record 22 of Set 14 | sioux lookout
# Processing record 23 of Set 14 | neftcala
# Processing record 24 of Set 14 | caraquet
# Processing record 25 of Set 14 | chuy
# Processing record 26 of Set 14 | arlit
# Processing record 27 of Set 14 | nizwa
# Processing record 28 of Set 14 | tekeli
# Processing record 29 of Set 14 | vila franca do campo
# Processing record 30 of Set 14 | meyungs
# City not found, skipping... meyungs
# Processing record 31 of Set 14 | russell
# Processing record 32 of Set 14 | dukat
# Processing record 33 of Set 14 | juarez
# Processing record 34 of Set 14 | labutta
# City not found, skipping... labutta
# Processing record 35 of Set 14 | karla
# Processing record 36 of Set 14 | hamilton
# Processing record 37 of Set 14 | tubruq
# City not found, skipping... tubruq
# Processing record 38 of Set 14 | gat
# Processing record 39 of Set 14 | porto-vecchio
# Processing record 40 of Set 14 | gobabis
# Processing record 41 of Set 14 | auki
# Processing record 42 of Set 14 | muroto
# Processing record 43 of Set 14 | stantsionno-oyashinskiy
# Processing record 44 of Set 14 | yulara
# Processing record 45 of Set 14 | wana
# Processing record 46 of Set 14 | camopi
# Processing record 47 of Set 14 | liaoyang
# Processing record 48 of Set 14 | tezu
# Processing record 49 of Set 14 | dabat
# Processing record 50 of Set 14 | barinas
# Processing record 1 of Set 15 | jamame
# Processing record 2 of Set 15 | ambilobe
# Processing record 3 of Set 15 | obo
# Processing record 4 of Set 15 | jiddah
# City not found, skipping... jiddah
# Processing record 5 of Set 15 | jinchang
# Processing record 6 of Set 15 | luderitz
# Processing record 7 of Set 15 | miranorte
# City not found, skipping... miranorte
# Processing record 8 of Set 15 | san quintin
# Processing record 9 of Set 15 | cervo
# Processing record 10 of Set 15 | ondorhaan
# City not found, skipping... ondorhaan
# Processing record 11 of Set 15 | bundaberg
# Processing record 12 of Set 15 | rey bouba
# Processing record 13 of Set 15 | mount isa
# Processing record 14 of Set 15 | sohag
# Processing record 15 of Set 15 | aguie
# Processing record 16 of Set 15 | dudinka
# Processing record 17 of Set 15 | phan thiet
# Processing record 18 of Set 15 | nachalovo
# Processing record 19 of Set 15 | bhola
# Processing record 20 of Set 15 | cairns
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Converting the array of dictionaries into a pandas dataframe
city_data_df = pd.DataFrame(city_data)

city_data_df.head()
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Saskylakh      RU  71.9167  114.0833      3.31        99          67
# 1     Atuona      PF  -9.8000 -139.0333     77.18        74          31
# 2   Udachnyy      RU  66.4167  112.4000     30.45        92         100
# 3   Hermanus      ZA -34.4187   19.2345     65.80        85          81
# 4    Lubango      AO -14.9172   13.4925     63.77        78          42
#
#    Wind Speed Current Description
# 0        5.77       broken clouds
# 1       17.34    scattered clouds
# 2       11.23                snow
# 3       14.76       broken clouds
# 4        2.39    scattered clouds

# %%
# Exporting the data to a csv file
# Creating the csv file
output_data_file = "WeatherPy_Database.csv"

# Exporting that data to the file
city_data_df.to_csv(output_data_file, index_label = "City_ID")
